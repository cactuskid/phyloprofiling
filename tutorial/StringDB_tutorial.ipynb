# %% [markdown]
# - Description of Notebook: This is for taking the SyntenyScore category slices, and running them through StringDB to see if there is a functional enrichment
# - Date: 28th May 2018
# - By: Natasha Glover

# %% [markdown]
# # Setup

# %%
# Scientific libraries
import numpy as np
from scipy import stats
import pandas as pd
from tables import *

#API libraries
import requests
import sys
from pandas.io.json import json_normalize
import time

# Pyoma libraries
from pyoma.browser import db
# from pyoma.browser import homoeologs

# Graphic libraries
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# Extra options
pd.set_option('max_colwidth',200)

# %%
#load in hdf5 database
h5file = open_file('/Users/nglover/OmaServerDec2017.h5', mode='r')
#Make pyoma objects
dbObj = db.Database(h5file)
omaIdObj = db.OmaIdMapper(dbObj)
xrefObj = db.XrefIdMapper(dbObj)
# Out:
# /usr/local/lib/python3.6/site-packages/tables/leaf.py:396: PerformanceWarning: The Leaf ``/Protein/_i_Entries/OmaHOG/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)

# %% [markdown]
# # Functions for stringDB

# %% [markdown]
# Highly recommended to read this tutorial from string! http://version10.string-db.org/help/api/ (This is where most of these functions are based on)

# %%
string_api_url = "https://string-db.org/api"
output_format = "json"
caller_identity  = "natasha.glover@unil.ch"
echo_query = "1"


def get_string_ids_from_xrefs(list_of_uniprot_ids, genome):
    '''Takes a list of xref ids, then returns a df of string ids, xrefs, and function annotations.
       Must give genome of query ids, to make it easier for string.'''
    
    final_df = pd.DataFrame()
    ncbitaxid = str(omaIdObj.genome_from_UniProtCode(genome)['NCBITaxonId'])
    method = "get_string_ids"
    limit=1
    number_of_requests = len(list_of_uniprot_ids)
    number_of_chunks = number_of_requests/500
    if number_of_requests > 500:
        chunks = np.array_split(list_of_uniprot_ids,np.ceil(number_of_chunks))  
    else:
        chunks = [list_of_uniprot_ids]
    for chunk in chunks:
        request_url = construct_string_request(string_api_url, output_format, chunk,
                                     ncbitaxid, method, limit, echo_query, caller_identity)

        response = requests.get(request_url)
        time.sleep(1)
        df = json_normalize(response.json())
        
    final_df = final_df.append(df)
    print("Number of query genes with stringid: "+ str(len(final_df)))

    return final_df


def get_string_interactors(list_of_string_ids, genome, limit=5):
    '''Gets the interactors based on stringids'''
    final_df = pd.DataFrame()
    ncbitaxid = str(omaIdObj.genome_from_UniProtCode(genome)['NCBITaxonId'])
    method = "interaction_partners"
    number_of_requests = len(list_of_string_ids)
    number_of_chunks = number_of_requests/200
    if number_of_requests > 200:
        chunks = np.array_split(list_of_string_ids,np.ceil(number_of_chunks))  
    else:
        chunks = [list_of_string_ids]
    for chunk in chunks:
        request_url = construct_string_request(string_api_url, output_format, chunk,
                                     ncbitaxid, method, limit, echo_query, caller_identity)

        response = requests.get(request_url)
        time.sleep(1)
        df = json_normalize(response.json())
        
        final_df = final_df.append(df)
        if len(final_df)> 0:
            return final_df
        else:
            return []

def construct_string_request(string_api_url, output_format, my_genes,
                             ncbitaxid, method, limit, echo_query, caller_identity):
    ## Construct the request
    request_url = string_api_url + "/" + output_format + "/" + method + "?"
    request_url += "identifiers=" + "%0d".join(my_genes)
    request_url += "&" + "species=" + ncbitaxid 
    request_url += "&" + "limit=" + str(limit)
    request_url += "&" + "echo_query=" + echo_query
    request_url += "&" + "caller_identity=" + caller_identity
    
    return request_url

def get_functional_enrichment(list_of_string_ids, genome):
    final_df = pd.DataFrame()
    ncbitaxid = str(omaIdObj.genome_from_UniProtCode(genome)['NCBITaxonId'])  
    method = "enrichment"
    number_of_requests = len(list_of_string_ids)
    number_of_chunks = number_of_requests/100
    if number_of_requests > 100:
        chunks = np.array_split(list_of_string_ids,np.ceil(number_of_chunks))  
    else:
        chunks = [list_of_string_ids]
    for chunk in chunks:
        request_url = string_api_url + "/" + output_format + "/" + method + "?"
        request_url += "identifiers=" + "%0d".join(chunk)
        request_url += "&" + "species=" + genome
        request_url += "&" + "caller_identity=" + caller_identity

        response = requests.get(request_url)
        time.sleep(1)
        df = json_normalize(response.json())
        
        final_df = final_df.append(df)
        if len(final_df)> 0:
            return final_df
        else:
            return []

#some functions for id conversion
def search(name, sourcelist):
    for x in sourcelist:
        if x['source'] == name:
            return x

# %% [markdown]
# # Example: Getting stringids, interactors, and functional enrichment for a list of genes

# %%
genes_of_interest = ["ARATH00006", "ARATH00007", "ARATH00008"]

# %% [markdown]
# First you need to get the string ids of your genes of interest somehow. So you have to get the cross-references (xref) from oma. An entrynr can have more than 1 xref, so you have to choose which one is best. I used the source id, but you can use uniprot ids or whatever.

# %%
#Example using 'SourceAC'

#map omaids to entrynrs
entrynrs = [omaIdObj.omaid_to_entry_nr(x) for x in genes_of_interest] 

#get xrefs for entrynrs
xrefs = [xrefObj.map_entry_nr(x) for x in entrynrs]

#search xrefs for the SourceAC
xrefs_source = [search('SourceAC',x)['xref'] for x in xrefs]

xrefs_source
# Out:
# ['ATCG00120.1', 'ATCG00130.1', 'ATCG00140.1']

# %%
#Example using Uniprot ids
xrefs = [xrefObj.map_entry_nr(x) for x in entrynrs]
xrefs_uniprot = [search('UniProtKB/SwissProt',x)['xref'] for x in xrefs]
xrefs_uniprot
# Out:
# ['ATPA_ARATH', 'ATPF_ARATH', 'ATPH_ARATH']

# %% [markdown]
# Get the string ids using the api. You can use either the list of sourceids or uniprot ids. Must give the genome which contains the genes, because it's needed for stringdb

# %%
stringids_df = get_string_ids_from_xrefs(xrefs_uniprot, "ARATH")
stringids = stringids_df['stringId']
stringids_df
# Out:
# Number of query genes with stringid: 3
#                                                                                                                                                                                                 annotation  \
# 0                                                      ATP synthase subunit alpha; Produces ATP from ADP in the presence of a proton gradient across the membrane. The alpha chain is a regulatory subunit
# 1  ATPase F subunit; F(1)F(0) ATP synthase produces ATP from ADP in the presence of a proton or sodium gradient. F-type ATPases consist of two structural domains, F(1) containing the extramembraneous...
# 2  ATPase III subunit; F(1)F(0) ATP synthase produces ATP from ADP in the presence of a proton or sodium gradient. F-type ATPases consist of two structural domains, F(1) containing the extramembraneo...
#
#    ncbiTaxonId preferredName  queryIndex   queryItem          stringId  \
# 0         3702          ATPA           0  ATPA_ARATH  3702.ATCG00120.1
# 1         3702          ATPF           1  ATPF_ARATH  3702.ATCG00130.1
# 2         3702          ATPH           2  ATPH_ARATH  3702.ATCG00140.1
#
#               taxonName
# 0  Arabidopsis thaliana
# 1  Arabidopsis thaliana
# 2  Arabidopsis thaliana

# %% [markdown]
# Get interactors of the 3 genes we just got the stringids for. Note you can control how many interactors to output by the limit parameter.

# %%
interactors_df = get_string_interactors(stringids, "ARATH", limit=10)
interactors_df
# Out:
#     ascore  dscore  escore  fscore ncbiTaxonId  nscore preferredName_A  \
# 0    0.988   0.772   0.930       0        3702   0.454            ATPA
# 1    0.988   0.772   0.930       0        3702   0.454            ATPA
# 2    0.988   0.772   0.970       0        3702   0.454            ATPA
# 3    0.988   0.772   0.938       0        3702   0.454            ATPA
# 4    0.983   0.772   0.923       0        3702   0.454            ATPA
# 5    0.983   0.772   0.923       0        3702   0.454            ATPA
# 6    0.988   0.772   0.938       0        3702   0.454            ATPA
# 7    0.990   0.772   0.936       0        3702   0.454            ATPA
# 8    0.988   0.772   0.862       0        3702   0.454            ATPA
# 9    0.992   0.772   0.967       0        3702   0.454            ATPA
# 10   0.961   0.525   0.936       0        3702   0.454            ATPF
# 11   0.928   0.772   0.914       0        3702   0.454            ATPF
# 12   0.928   0.772   0.914       0        3702   0.454            ATPF
# 13   0.919   0.772   0.928       0        3702   0.454            ATPF
# 14   0.919   0.772   0.928       0        3702   0.454            ATPF
# 15   0.990   0.772   0.936       0        3702   0.454            ATPF
# 16   0.987   0.772   0.914       0        3702   0.454            ATPF
# 17   0.547   0.772   0.925       0        3702   0.454            ATPF
# 18   0.934   0.772   0.928       0        3702   0.454            ATPF
# 19   0.953   0.772   0.936       0        3702   0.454            ATPF
# 20   0.949   0.525   0.862       0        3702   0.454            ATPH
# 21   0.788   0.772   0.862       0        3702   0.454            ATPH
# 22   0.721   0.772   0.900       0        3702   0.454            ATPH
# 23   0.804   0.772   0.836       0        3702   0.454            ATPH
# 24   0.988   0.772   0.862       0        3702   0.454            ATPH
# 25   0.987   0.772   0.914       0        3702   0.454            ATPH
# 26   0.942   0.772   0.836       0        3702   0.454            ATPH
# 27   0.627   0.772   0.900       0        3702   0.454            ATPH
# 28   0.847   0.772   0.836       0        3702   0.454            ATPH
# 29   0.944   0.772   0.862       0        3702   0.454            ATPH
#
#    preferredName_B    pscore  score   stringId_A   stringId_B    tscore
# 0            ATPC2  0.510000  0.999  ATCG00120.1  AT1G15700.1  0.655000
# 1             ATP3  0.510000  0.999  ATCG00120.1  AT2G33040.1  0.574000
# 2            ATPC1  0.506000  0.999  ATCG00120.1  AT4G04640.1  0.727000
# 3             ATPD  0.000000  0.999  ATCG00120.1  AT4G09650.1  0.592000
# 4        AT5G08680  0.183855  0.999  ATCG00120.1  AT5G08680.1  0.168861
# 5        AT5G08690  0.183340  0.999  ATCG00120.1  AT5G08690.1  0.168388
# 6             ATP5  0.000000  0.999  ATCG00120.1  AT5G13450.1  0.687000
# 7             ATPF  0.000000  0.999  ATCG00120.1  ATCG00130.1  0.439000
# 8             ATPH  0.000000  0.999  ATCG00120.1  ATCG00140.1  0.477000
# 9               PB  0.185802  0.999  ATCG00120.1  ATCG00480.1  0.243798
# 10       AT2G07698  0.000000  0.999  ATCG00130.1  AT2G07698.1  0.359000
# 11       AT2G25610  0.000000  0.999  ATCG00130.1  AT2G25610.1  0.200000
# 12          VHA-C3  0.000000  0.999  ATCG00130.1  AT4G38920.1  0.200000
# 13       AT5G08680  0.000000  0.999  ATCG00130.1  AT5G08680.1  0.182000
# 14       AT5G08690  0.000000  0.999  ATCG00130.1  AT5G08690.1  0.182000
# 15            ATPA  0.000000  0.999  ATCG00130.1  ATCG00120.1  0.439000
# 16            ATPH  0.000000  0.999  ATCG00130.1  ATCG00140.1  0.924000
# 17            ATPE  0.000000  0.999  ATCG00130.1  ATCG00470.1  0.865000
# 18              PB  0.000000  0.999  ATCG00130.1  ATCG00480.1  0.881000
# 19            ATP1  0.000000  0.999  ATCG00130.1  ATMG01190.1  0.505000
# 20       AT2G07698  0.000000  0.998  ATCG00140.1  AT2G07698.1  0.372000
# 21            ATP3  0.000000  0.998  ATCG00140.1  AT2G33040.1  0.538000
# 22            ATPD  0.000000  0.997  ATCG00140.1  AT4G09650.1  0.341000
# 23       AT5G08690  0.000000  0.997  ATCG00140.1  AT5G08690.1  0.442000
# 24            ATPA  0.000000  0.999  ATCG00140.1  ATCG00120.1  0.477000
# 25            ATPF  0.000000  0.999  ATCG00140.1  ATCG00130.1  0.924000
# 26            ATPI  0.298000  0.999  ATCG00140.1  ATCG00150.1  0.937000
# 27            ATPE  0.000000  0.999  ATCG00140.1  ATCG00470.1  0.859000
# 28              PB  0.000000  0.999  ATCG00140.1  ATCG00480.1  0.839000
# 29            ATP1  0.000000  0.999  ATCG00140.1  ATMG01190.1  0.423000

# %% [markdown]
# Now get the functional enrichment of the interactors, or really just the functional enrichment of any list of genes

# %%
#functional enrichment of original 3 genes
get_functional_enrichment(stringids, "ARATH")
# Out:
#       bonferroni   category  \
# 0   4.120000e-06    Process
# 1   2.430000e-02    Process
# 2   2.540000e-06       KEGG
# 3   3.600000e-02       KEGG
# 4   1.910000e-05       KEGG
# 5   1.080000e-03  Component
# 6   1.000000e+00  Component
# 7   1.000000e+00  Component
# 8   1.990000e-03  Component
# 9   1.000000e+00  Component
# 10  5.550000e-04  Component
# 11  1.000000e+00  Component
# 12  4.500000e-07  Component
# 13  2.180000e-01  Component
# 14  1.000000e+00   Function
# 15  2.110000e-04   Function
# 16  1.000000e+00   Function
# 17  2.410000e-03   Function
#
#                                                         description  \
# 0                            ATP synthesis coupled proton transport
# 1                           ATP hydrolysis coupled proton transport
# 2                                                    Photosynthesis
# 3                                                Metabolic pathways
# 4                                         Oxidative phosphorylation
# 5                                    chloroplast thylakoid membrane
# 6                                                     intracellular
# 7                                                         cytoplasm
# 8                                             chloroplast thylakoid
# 9                                                              cell
# 10   proton-transporting ATP synthase complex, coupling factor F(o)
# 11                                   integral component of membrane
# 12                         proton-transporting ATP synthase complex
# 13                                                      chloroplast
# 14                                                      ATP binding
# 15                  hydrogen ion transmembrane transporter activity
# 16                                                          binding
# 17  proton-transporting ATP synthase activity, rotational mechanism
#
#              fdr                                              inputGenes  \
# 0   2.060000e-06  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 1   4.260000e-04                    [3702.ATCG00120.1, 3702.ATCG00140.1]
# 2   2.540000e-06  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 3   1.200000e-02  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 4   9.540000e-06  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 5   1.530000e-04  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 6   7.110000e-01  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 7   3.140000e-01  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 8   1.800000e-04  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 9   9.310000e-01  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 10  1.530000e-04                    [3702.ATCG00130.1, 3702.ATCG00140.1]
# 11  8.150000e-01                    [3702.ATCG00130.1, 3702.ATCG00140.1]
# 12  4.500000e-07  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 13  1.150000e-02  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 14  9.740000e-01                    [3702.ATCG00120.1, 3702.ATCG00130.1]
# 15  2.110000e-04  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 16  9.740000e-01  [3702.ATCG00120.1, 3702.ATCG00130.1, 3702.ATCG00140.1]
# 17  6.690000e-04                    [3702.ATCG00120.1, 3702.ATCG00130.1]
#
#     ncbiTaxonId  number_of_genes       p_value      preferredNames        term
# 0          3702                3  8.520000e-10  [ATPA, ATPF, ATPH]  GO:0015986
# 1          3702                2  5.030000e-06        [ATPA, ATPH]  GO:0015991
# 2          3702                3  1.970000e-08  [ATPA, ATPF, ATPH]       00195
# 3          3702                3  2.790000e-04  [ATPA, ATPF, ATPH]       01100
# 4          3702                3  1.480000e-07  [ATPA, ATPF, ATPH]       00190
# 5          3702                3  1.420000e-06  [ATPA, ATPF, ATPH]  GO:0009535
# 6          3702                3  2.980000e-02  [ATPA, ATPF, ATPH]  GO:0005622
# 7          3702                3  1.070000e-02  [ATPA, ATPF, ATPH]  GO:0005737
# 8          3702                3  2.600000e-06  [ATPA, ATPF, ATPH]  GO:0009534
# 9          3702                3  4.390000e-02  [ATPA, ATPF, ATPH]  GO:0005623
# 10         3702                2  7.260000e-07        [ATPF, ATPH]  GO:0045263
# 11         3702                2  3.520000e-02        [ATPF, ATPH]  GO:0016021
# 12         3702                3  5.890000e-10  [ATPA, ATPF, ATPH]  GO:0045259
# 13         3702                3  2.850000e-04  [ATPA, ATPF, ATPH]  GO:0009507
# 14         3702                2  1.140000e-02        [ATPA, ATPF]  GO:0005524
# 15         3702                3  8.390000e-08  [ATPA, ATPF, ATPH]  GO:0015078
# 16         3702                3  1.390000e-02  [ATPA, ATPF, ATPH]  GO:0005488
# 17         3702                2  9.580000e-07        [ATPA, ATPF]  GO:0046933

# %%
#functional enrichment of the interactors of the 3 genes
interactors_stringids = interactors_df['stringId_B']
interactors_stringids
# Out:
# 0     AT1G15700.1
# 1     AT2G33040.1
# 2     AT4G04640.1
# 3     AT4G09650.1
# 4     AT5G08680.1
# 5     AT5G08690.1
# 6     AT5G13450.1
# 7     ATCG00130.1
# 8     ATCG00140.1
# 9     ATCG00480.1
# 10    AT2G07698.1
# 11    AT2G25610.1
# 12    AT4G38920.1
# 13    AT5G08680.1
# 14    AT5G08690.1
# 15    ATCG00120.1
# 16    ATCG00140.1
# 17    ATCG00470.1
# 18    ATCG00480.1
# 19    ATMG01190.1
# 20    AT2G07698.1
# 21    AT2G33040.1
# 22    AT4G09650.1
# 23    AT5G08690.1
# 24    ATCG00120.1
# 25    ATCG00130.1
# 26    ATCG00150.1
# 27    ATCG00470.1
# 28    ATCG00480.1
# 29    ATMG01190.1
# Name: stringId_B, dtype: object

# %%
get_functional_enrichment(interactors_stringids, "ARATH")
# Out:
#       bonferroni   category  \
# 0   3.280000e-02       Pfam
# 1   5.470000e-03       Pfam
# 2   5.470000e-03       Pfam
# 3   5.470000e-03       Pfam
# 4   4.010000e-03    Process
# 5   1.000000e+00    Process
# 6   4.270000e-02    Process
# 7   4.890000e-02    Process
# 8   1.000000e+00    Process
# 9   7.170000e-06    Process
# 10  1.000000e+00    Process
# 11  4.250000e-38    Process
# 12  4.460000e-16    Process
# 13  1.590000e-27    Process
# 14  1.000000e+00    Process
# 15  1.000000e+00    Process
# 16  9.340000e-03   InterPro
# 17  9.340000e-03   InterPro
# 18  1.000000e+00   InterPro
# 19  4.670000e-03   InterPro
# 20  1.560000e-03   InterPro
# 21  9.340000e-03   InterPro
# 22  5.590000e-02   InterPro
# 23  9.340000e-03   InterPro
# 24  1.610000e-17       KEGG
# 25  2.170000e-16       KEGG
# 26  3.910000e-34       KEGG
# 27  1.400000e-01       KEGG
# 28  1.520000e-02  Component
# 29  8.390000e-06  Component
# ..           ...        ...
# 40  4.240000e-26  Component
# 41  1.220000e-03  Component
# 42  4.110000e-03  Component
# 43  1.930000e-09  Component
# 44  3.650000e-09  Component
# 45  6.800000e-03  Component
# 46  1.000000e+00  Component
# 47  1.000000e+00  Component
# 48  2.760000e-04  Component
# 49  1.000000e+00  Component
# 50  5.720000e-36  Component
# 51  1.000000e+00  Component
# 52  2.220000e-08  Component
# 53  1.560000e-04  Component
# 54  1.510000e-06  Component
# 55  4.000000e-38  Component
# 56  1.000000e+00  Component
# 57  5.480000e-05  Component
# 58  1.000000e-06  Component
# 59  1.080000e-01   Function
# 60  1.000000e+00   Function
# 61  1.000000e+00   Function
# 62  1.000000e+00   Function
# 63  1.000000e+00   Function
# 64  1.000000e+00   Function
# 65  1.000000e+00   Function
# 66  1.000000e+00   Function
# 67  3.140000e-34   Function
# 68  4.230000e-39   Function
# 69  9.750000e-13   Function
#
#                                                                   description  \
# 0                                                      ATP synthase subunit C
# 1                          ATP synthase alpha/beta family, beta-barrel domain
# 2                            ATP synthase alpha/beta chain, C terminal domain
# 3                   ATP synthase alpha/beta family, nucleotide-binding domain
# 4                                            single-organism cellular process
# 5                                              photosynthesis, light reaction
# 6                                                  cellular metabolic process
# 7                         photosynthetic electron transport in photosystem II
# 8                                                           metabolic process
# 9                                           single-organism metabolic process
# 10                                           regulation of catalytic activity
# 11                                     ATP synthesis coupled proton transport
# 12                                    ATP hydrolysis coupled proton transport
# 13                                       hydrogen ion transmembrane transport
# 14                                                         biological_process
# 15                                                             photosynthesis
# 16                   ATPase, F1/V1/A1 complex, alpha/beta subunit, C-terminal
# 17                   ATPase, F1 complex alpha/beta subunit, N-terminal domain
# 18                        P-loop containing nucleoside triphosphate hydrolase
# 19                                     ATP synthase subunit alpha-like domain
# 20                                          ATPase, F1 complex, alpha subunit
# 21         ATPase, alpha/beta subunit, nucleotide-binding domain, active site
# 22                                 V-ATPase proteolipid subunit C-like domain
# 23    ATPase, F1/V1/A1 complex, alpha/beta subunit, nucleotide-binding domain
# 24                                                             Photosynthesis
# 25                                                         Metabolic pathways
# 26                                                  Oxidative phosphorylation
# 27                                                                  Phagosome
# 28                               proton-transporting V-type ATPase, V0 domain
# 29                                                                   membrane
# ..                                                                        ...
# 40              proton-transporting ATP synthase complex, catalytic core F(1)
# 41                                                              intracellular
# 42                                               mitochondrial inner membrane
# 43  proton-transporting two-sector ATPase complex, proton-transporting domain
# 44                                               intracellular organelle part
# 45                                                         organelle envelope
# 46                                                              nuclear lumen
# 47                                                                  nucleolus
# 48                                           chloroplast ATP synthase complex
# 49                                             integral component of membrane
# 50                                   proton-transporting ATP synthase complex
# 51                                                              mitochondrion
# 52                                                                chloroplast
# 53                                   intracellular membrane-bounded organelle
# 54                     mitochondrial proton-transporting ATP synthase complex
# 55                              proton-transporting two-sector ATPase complex
# 56                                                                    vacuole
# 57             proton-transporting ATP synthase complex, coupling factor F(o)
# 58                                                           cytoplasmic part
# 59                                                                ATP binding
# 60                                                  enzyme regulator activity
# 61                                               transition metal ion binding
# 62                                                                    binding
# 63                                                                ion binding
# 64                                                         molecular_function
# 65                                                         copper ion binding
# 66                                                           zinc ion binding
# 67                            hydrogen ion transmembrane transporter activity
# 68            proton-transporting ATP synthase activity, rotational mechanism
# 69                  proton-transporting ATPase activity, rotational mechanism
#
#              fdr  \
# 0   8.190000e-03
# 1   1.820000e-03
# 2   1.820000e-03
# 3   1.820000e-03
# 4   4.460000e-05
# 5   5.900000e-02
# 6   4.640000e-04
# 7   5.210000e-04
# 8   1.560000e-01
# 9   8.150000e-08
# 10  6.750000e-01
# 11  2.130000e-38
# 12  7.310000e-18
# 13  7.220000e-29
# 14  7.280000e-02
# 15  2.930000e-01
# 16  1.560000e-03
# 17  1.560000e-03
# 18  1.000000e+00
# 19  1.560000e-03
# 20  1.560000e-03
# 21  1.560000e-03
# 22  7.990000e-03
# 23  1.560000e-03
# 24  8.040000e-18
# 25  7.220000e-17
# 26  3.910000e-34
# 27  3.500000e-02
# 28  3.290000e-04
# 29  3.110000e-07
# ..           ...
# 40  1.410000e-26
# 41  3.390000e-05
# 42  1.090000e-04
# 43  1.210000e-10
# 44  2.030000e-10
# 45  1.710000e-04
# 46  5.240000e-01
# 47  1.700000e-01
# 48  8.130000e-06
# 49  1.120000e-01
# 50  2.860000e-36
# 51  4.310000e-02
# 52  1.060000e-09
# 53  5.060000e-06
# 54  5.810000e-08
# 55  4.000000e-38
# 56  8.280000e-01
# 57  1.890000e-06
# 58  4.000000e-08
# 59  3.600000e-03
# 60  3.500000e-01
# 61  1.800000e-01
# 62  1.220000e-01
# 63  3.060000e-02
# 64  1.000000e+00
# 65  1.810000e-01
# 66  1.000000e+00
# 67  1.050000e-34
# 68  4.230000e-39
# 69  3.750000e-14
#
#                                                                                                                                                                                                  inputGenes  \
# 0                                                                                                                                                                                [AT4G38920.1, ATCG00140.1]
# 1                                                                                                                                                                                [AT2G07698.1, ATMG01190.1]
# 2                                                                                                                                                                                [AT2G07698.1, ATMG01190.1]
# 3                                                                                                                                                                                [AT2G07698.1, ATMG01190.1]
# 4                                 [AT2G25610.1, AT2G33040.1, AT4G38920.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 5                                                                                                                                                                                [AT4G04640.1, AT4G09650.1]
# 6                                 [AT1G15700.1, AT2G33040.1, AT4G04640.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 7                                                                                                                                                                                [AT4G04640.1, AT4G09650.1]
# 8                                                           [AT2G33040.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 9                                 [AT1G15700.1, AT2G33040.1, AT4G04640.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 10                                                                                                                                                                               [AT1G15700.1, AT4G04640.1]
# 11                   [AT1G15700.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 12                                                                                                 [AT2G25610.1, AT4G38920.1, AT5G08680.1, AT5G08690.1, ATCG00120.1, ATCG00140.1, ATCG00480.1, ATMG01190.1]
# 13                   [AT2G25610.1, AT2G33040.1, AT4G09650.1, AT4G38920.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 14                                [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G38920.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 15                                                                                                                                                                               [AT4G04640.1, AT4G09650.1]
# 16                                                                                                                                                                               [AT2G07698.1, ATMG01190.1]
# 17                                                                                                                                                                               [AT2G07698.1, ATMG01190.1]
# 18                                                                                                                                                                               [AT2G07698.1, ATMG01190.1]
# 19                                                                                                                                                                               [AT2G07698.1, ATMG01190.1]
# 20                                                                                                                                                                               [AT2G07698.1, ATMG01190.1]
# 21                                                                                                                                                                               [AT2G07698.1, ATMG01190.1]
# 22                                                                                                                                                                               [AT4G38920.1, ATCG00140.1]
# 23                                                                                                                                                                               [AT2G07698.1, ATMG01190.1]
# 24                                                                                    [AT1G15700.1, AT4G04640.1, AT4G09650.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1]
# 25  [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT4G38920.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ...
# 26  [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT4G38920.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ...
# 27                                                                                                                                                                               [AT2G25610.1, AT4G38920.1]
# 28                                                                                                                                                                               [AT2G25610.1, AT4G38920.1]
# 29                   [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT5G08680.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# ..                                                                                                                                                                                                      ...
# 40                                                                                    [AT1G15700.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT5G08680.1, ATCG00120.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 41      [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT4G38920.1, AT5G08680.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 42                                                                                                                                                     [AT2G33040.1, AT5G08680.1, AT5G13450.1, ATMG01190.1]
# 43                                                                                                                                        [AT2G25610.1, AT4G38920.1, ATCG00130.1, ATCG00140.1, ATCG00150.1]
# 44      [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT4G38920.1, AT5G08680.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 45                                                                                                                           [AT2G33040.1, AT4G04640.1, AT4G09650.1, AT5G08680.1, AT5G13450.1, ATMG01190.1]
# 46                                                                                                                                                                               [AT2G33040.1, AT5G08690.1]
# 47                                                                                                                                                                               [AT2G33040.1, AT5G08690.1]
# 48                                                                                                                                                                               [AT1G15700.1, AT4G04640.1]
# 49                                                                                                                           [AT2G25610.1, AT4G38920.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATMG01190.1]
# 50                                [AT1G15700.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT5G08680.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 51                                                                                                                                                     [AT2G33040.1, AT5G08680.1, AT5G13450.1, ATMG01190.1]
# 52                                             [AT1G15700.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1]
# 53      [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT4G38920.1, AT5G08680.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 54                                                                                                                                                                  [AT2G33040.1, AT5G08680.1, AT5G13450.1]
# 55      [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT4G38920.1, AT5G08680.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 56                                                                                                                                                                               [AT2G25610.1, AT4G38920.1]
# 57                                                                                                                                                                  [ATCG00130.1, ATCG00140.1, ATCG00150.1]
# 58      [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT4G38920.1, AT5G08680.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 59                                                                                                              [AT5G08680.1, AT5G08690.1, ATCG00120.1, ATCG00130.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 60                                                                                                                                                                               [AT1G15700.1, AT4G04640.1]
# 61                                                                                                                                                     [AT2G33040.1, AT5G08680.1, AT5G08690.1, AT5G13450.1]
# 62                                                                       [AT2G33040.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 63                                                                                    [AT2G33040.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 64                                                                       [AT2G25610.1, AT4G09650.1, AT4G38920.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 65                                                                                                                                                                               [AT5G08680.1, AT5G08690.1]
# 66                                                                                                                                                                               [AT2G33040.1, AT5G13450.1]
# 67  [AT1G15700.1, AT2G25610.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT4G38920.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00140.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ...
# 68                                [AT1G15700.1, AT2G33040.1, AT4G04640.1, AT4G09650.1, AT5G08680.1, AT5G08690.1, AT5G13450.1, ATCG00120.1, ATCG00130.1, ATCG00150.1, ATCG00470.1, ATCG00480.1, ATMG01190.1]
# 69                                                                                                                           [AT1G15700.1, AT2G33040.1, AT4G04640.1, ATCG00120.1, ATCG00470.1, ATMG01190.1]
#
#     ncbiTaxonId  number_of_genes       p_value  \
# 0          3702                2  1.300000e-05
# 1          3702                2  2.170000e-06
# 2          3702                2  2.170000e-06
# 3          3702                2  2.170000e-06
# 4          3702               13  8.290000e-07
# 5          3702                2  1.200000e-03
# 6          3702               13  8.840000e-06
# 7          3702                2  1.010000e-05
# 8          3702               11  3.230000e-03
# 9          3702               13  1.480000e-09
# 10         3702                2  1.440000e-02
# 11         3702               14  8.790000e-42
# 12         3702                8  9.230000e-20
# 13         3702               14  3.290000e-31
# 14         3702               13  1.490000e-03
# 15         3702                2  6.130000e-03
# 16         3702                2  2.170000e-06
# 17         3702                2  2.170000e-06
# 18         3702                2  3.820000e-02
# 19         3702                2  1.090000e-06
# 20         3702                2  3.620000e-07
# 21         3702                2  2.170000e-06
# 22         3702                2  1.300000e-05
# 23         3702                2  2.170000e-06
# 24         3702                9  1.250000e-19
# 25         3702               16  1.680000e-18
# 26         3702               16  3.030000e-36
# 27         3702                2  1.080000e-03
# 28         3702                2  1.980000e-05
# 29         3702               14  1.100000e-08
# ..          ...              ...           ...
# 40         3702                9  5.550000e-29
# 41         3702               15  1.600000e-06
# 42         3702                4  5.380000e-06
# 43         3702                5  2.530000e-12
# 44         3702               15  4.780000e-12
# 45         3702                6  8.900000e-06
# 46         3702                2  4.120000e-02
# 47         3702                2  1.310000e-02
# 48         3702                2  3.620000e-07
# 49         3702                6  8.370000e-03
# 50         3702               13  7.490000e-39
# 51         3702                4  2.990000e-03
# 52         3702               12  2.910000e-11
# 53         3702               15  2.040000e-07
# 54         3702                3  1.980000e-09
# 55         3702               15  5.240000e-41
# 56         3702                2  7.150000e-02
# 57         3702                3  7.180000e-08
# 58         3702               15  1.310000e-09
# 59         3702                7  4.300000e-05
# 60         3702                2  6.960000e-03
# 61         3702                4  3.440000e-03
# 62         3702               10  2.280000e-03
# 63         3702                9  5.590000e-04
# 64         3702               10  2.330000e-02
# 65         3702                2  3.540000e-03
# 66         3702                2  5.820000e-02
# 67         3702               16  1.250000e-37
# 68         3702               13  1.680000e-42
# 69         3702                6  3.880000e-16
#
#                                                                                                        preferredNames  \
# 0                                                                                                      [VHA-C3, ATPH]
# 1                                                                                                   [AT2G07698, ATP1]
# 2                                                                                                   [AT2G07698, ATP1]
# 3                                                                                                   [AT2G07698, ATP1]
# 4                       [AT2G25610, ATP3, VHA-C3, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 5                                                                                                       [ATPC1, ATPD]
# 6                            [ATPC2, ATP3, ATPC1, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 7                                                                                                       [ATPC1, ATPD]
# 8                                          [ATP3, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 9                            [ATPC2, ATP3, ATPC1, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 10                                                                                                     [ATPC2, ATPC1]
# 11                     [ATPC2, ATP3, ATPC1, ATPD, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 12                                                    [AT2G25610, VHA-C3, AT5G08680, AT5G08690, ATPA, ATPH, PB, ATP1]
# 13                [AT2G25610, ATP3, ATPD, VHA-C3, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 14                          [ATPC2, AT2G25610, ATP3, VHA-C3, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 15                                                                                                      [ATPC1, ATPD]
# 16                                                                                                  [AT2G07698, ATP1]
# 17                                                                                                  [AT2G07698, ATP1]
# 18                                                                                                  [AT2G07698, ATP1]
# 19                                                                                                  [AT2G07698, ATP1]
# 20                                                                                                  [AT2G07698, ATP1]
# 21                                                                                                  [AT2G07698, ATP1]
# 22                                                                                                     [VHA-C3, ATPH]
# 23                                                                                                  [AT2G07698, ATP1]
# 24                                                             [ATPC2, ATPC1, ATPD, ATPA, ATPF, ATPH, ATPI, ATPE, PB]
# 25  [ATPC2, AT2G25610, ATP3, ATPC1, ATPD, VHA-C3, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 26  [ATPC2, AT2G25610, ATP3, ATPC1, ATPD, VHA-C3, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 27                                                                                                [AT2G25610, VHA-C3]
# 28                                                                                                [AT2G25610, VHA-C3]
# 29                     [ATPC2, AT2G25610, ATP3, ATPC1, ATPD, AT5G08680, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# ..                                                                                                                ...
# 40                                                        [ATPC2, ATP3, ATPC1, ATPD, AT5G08680, ATPA, ATPE, PB, ATP1]
# 41             [ATPC2, AT2G25610, ATP3, ATPC1, ATPD, VHA-C3, AT5G08680, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 42                                                                                      [ATP3, AT5G08680, ATP5, ATP1]
# 43                                                                              [AT2G25610, VHA-C3, ATPF, ATPH, ATPI]
# 44             [ATPC2, AT2G25610, ATP3, ATPC1, ATPD, VHA-C3, AT5G08680, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 45                                                                         [ATP3, ATPC1, ATPD, AT5G08680, ATP5, ATP1]
# 46                                                                                                  [ATP3, AT5G08690]
# 47                                                                                                  [ATP3, AT5G08690]
# 48                                                                                                     [ATPC2, ATPC1]
# 49                                                                        [AT2G25610, VHA-C3, ATPF, ATPH, ATPI, ATP1]
# 50                                [ATPC2, ATP3, ATPC1, ATPD, AT5G08680, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 51                                                                                      [ATP3, AT5G08680, ATP5, ATP1]
# 52                                      [ATPC2, ATP3, ATPC1, ATPD, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB]
# 53             [ATPC2, AT2G25610, ATP3, ATPC1, ATPD, VHA-C3, AT5G08680, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 54                                                                                            [ATP3, AT5G08680, ATP5]
# 55             [ATPC2, AT2G25610, ATP3, ATPC1, ATPD, VHA-C3, AT5G08680, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 56                                                                                                [AT2G25610, VHA-C3]
# 57                                                                                                 [ATPF, ATPH, ATPI]
# 58             [ATPC2, AT2G25610, ATP3, ATPC1, ATPD, VHA-C3, AT5G08680, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 59                                                                 [AT5G08680, AT5G08690, ATPA, ATPF, ATPE, PB, ATP1]
# 60                                                                                                     [ATPC2, ATPC1]
# 61                                                                                 [ATP3, AT5G08680, AT5G08690, ATP5]
# 62                                               [ATP3, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPE, PB, ATP1]
# 63                                                     [ATP3, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPE, PB, ATP1]
# 64                                                  [AT2G25610, ATPD, VHA-C3, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 65                                                                                             [AT5G08680, AT5G08690]
# 66                                                                                                       [ATP3, ATP5]
# 67  [ATPC2, AT2G25610, ATP3, ATPC1, ATPD, VHA-C3, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPH, ATPI, ATPE, PB, ATP1]
# 68                           [ATPC2, ATP3, ATPC1, ATPD, AT5G08680, AT5G08690, ATP5, ATPA, ATPF, ATPI, ATPE, PB, ATP1]
# 69                                                                             [ATPC2, ATP3, ATPC1, ATPA, ATPE, ATP1]
#
#           term
# 0      PF00137
# 1      PF02874
# 2      PF00306
# 3      PF00006
# 4   GO:0044763
# 5   GO:0019684
# 6   GO:0044237
# 7   GO:0009772
# 8   GO:0008152
# 9   GO:0044710
# 10  GO:0050790
# 11  GO:0015986
# 12  GO:0015991
# 13  GO:1902600
# 14  GO:0008150
# 15  GO:0015979
# 16   IPR000793
# 17   IPR004100
# 18   IPR027417
# 19   IPR023366
# 20   IPR005294
# 21   IPR020003
# 22   IPR002379
# 23   IPR000194
# 24       00195
# 25       01100
# 26       00190
# 27       04145
# 28  GO:0033179
# 29  GO:0016020
# ..         ...
# 40  GO:0045261
# 41  GO:0005622
# 42  GO:0005743
# 43  GO:0033177
# 44  GO:0044446
# 45  GO:0031967
# 46  GO:0031981
# 47  GO:0005730
# 48  GO:0009544
# 49  GO:0016021
# 50  GO:0045259
# 51  GO:0005739
# 52  GO:0009507
# 53  GO:0043231
# 54  GO:0005753
# 55  GO:0016469
# 56  GO:0005773
# 57  GO:0045263
# 58  GO:0044444
# 59  GO:0005524
# 60  GO:0030234
# 61  GO:0046914
# 62  GO:0005488
# 63  GO:0043167
# 64  GO:0003674
# 65  GO:0005507
# 66  GO:0008270
# 67  GO:0015078
# 68  GO:0046933
# 69  GO:0046961
#
# [70 rows x 10 columns]
