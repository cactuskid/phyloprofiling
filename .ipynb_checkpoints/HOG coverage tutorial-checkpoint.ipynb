# %% [markdown]
# - Description of Notebook: HOG Species Coverage
# - Date: 19 June 2018
# - By: Natasha Glover

# %% [markdown]
# # Setup

# %%
from tables import *
import requests
import json
from pyoma.browser import db
import pandas as pd
import numpy as np

# %%
#load in hdf5 database
h5file = open_file('/Users/nglover/OmaServerDec2017.h5', mode='r')

#Make pyoma objects
dbObj = db.Database(h5file)
omaIdObj = db.OmaIdMapper(dbObj)

#these is a global dataframe
entries_df = pd.DataFrame(h5file.root.Protein.Entries.read())
# Out:
# /usr/local/lib/python3.6/site-packages/tables/leaf.py:396: PerformanceWarning: The Leaf ``/Protein/_i_Entries/OmaHOG/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)

# %%
#these are the functions you will need

def get_all_genomes(taxa_level):
    '''Uses the OMA API to get all the 5-letter species codes below a given taxonomy level'''
    
    def traverse(data):
        '''data is a dictionary'''
        for child in data['children']:
            try:
                traverse(child)
            except:
                #print(child['name'])
                myspecies.append(child['id'])
                pass

    myspecies = []
    
    json = requests.get("https://omabrowser.org/api/taxonomy/"+ taxa_level + "/").json()
    traverse(json)
    
    genome_df = pd.DataFrame(h5file.root.Genome.read())
    myspecies = [genome_df[genome_df["NCBITaxonId"]==x]['SciName'].item().decode() for x in myspecies]

    return(myspecies)

def make_tax_dic(genomes_list_scinames):
    #make a dictionary which contains all the taxa levels in the database and
    #a list of genomes under that taxa level
    mytax_dic = {} 
    taxObj = db.Taxonomy(h5file.root.Taxonomy.read())
    genome_df = pd.DataFrame(h5file.root.Genome.read())
        
    for species in genomes_list_scinames:
        ncbitaxonid = genome_df[genome_df["SciName"]==species.encode("utf-8")]['NCBITaxonId'].item()
        taxa = taxObj.get_parent_taxa(ncbitaxonid)
        taxa = [x[2].decode() for x in taxa]
        for tax in taxa:
            if tax in mytax_dic.keys():
                if species not in mytax_dic[tax]:
                    mytax_dic[tax].append(species)
            else:
                mytax_dic[tax] = [species]

    all_species = mytax_dic.values()
    flat_list = [item for sublist in all_species for item in sublist]
    
    #Add a LUCA key with all the species in our current dict
    all_species = list(set(flat_list))
    mytax_dic['LUCA'] = all_species
    return (mytax_dic)

def member_of_hog_id_v2(hog_id, taxon_level, mytax_dic):
    '''returns all entrynrs in a hog given a taxonomic level'''
    family = int(hog_id.split(":")[1].split(".")[0])
    mytaxa = [x for x in mytax_dic[taxon_level] ]
    subhogs_tmp = [dbObj.get_subhogids_at_level(family, x) for x in mytaxa]
    subhogs = np.unique(np.concatenate(subhogs_tmp))
    entrynrs = entries_df[entries_df['OmaHOG'].isin(subhogs)]['EntryNr']
    entrynrs = [x for x in entrynrs if omaIdObj.genome_of_entry_nr(x)[5].decode() in mytax_dic[taxon_level]]
    return (entrynrs)

def get_nb_species_in_hog_v2(fam_or_hogid, taxon_level, mytax_dic):
    '''Counts the number of species given a hog id or family number'''
    if isinstance(fam_or_hogid, int):
        hog_family = fam_or_hogid
        hog_id = 'HOG:'+'{:05}'.format(fam_or_hogid)
    if isinstance(fam_or_hogid, str):
        hog_id = fam_or_hogid
    entrynrs = member_of_hog_id_v2(hog_id, taxon_level, mytax_dic) #this needs a HOG:xxxxx format
    genomes = [omaIdObj.genome_of_entry_nr(entrynr)[1].decode("utf-8") for entrynr in entrynrs]
    return (len(set(genomes)))

def get_hog_coverage(fam_or_hogid, taxon_level, mytax_dic):
    '''enter a family (int) or hog id (str), returns the number of 
    species in that HOG out of the total number of species that *could* be in the HOG'''
    if isinstance(fam_or_hogid, int):
        hog_id = fam_or_hogid
    if isinstance(fam_or_hogid, str):
        hog_id = fam_or_hogid
    
    nb_species_in_hog = get_nb_species_in_hog_v2(fam_or_hogid, taxon_level, mytax_dic)
    nb_species_possible_in_hog = len(list(set(mytax_dic[taxon_level])))
    hog_coverage = nb_species_in_hog/ nb_species_possible_in_hog
    return nb_species_in_hog, nb_species_possible_in_hog, hog_coverage

# %% [markdown]
# # Example: HOG Species Coverage for a hog at the Viridiplantae level

# %% [markdown]
# Get all genomes at the taxonomic level of interest. For this example, I only care about the green plants (Viridiplantae) level:

# %%
all_plant_genomes = get_all_genomes("Viridiplantae")
print(all_plant_genomes)
# Out:
# ['Chlamydomonas reinhardtii', 'Volvox carteri', 'Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)', 'Micromonas pusilla (strain CCMP1545)', 'Ostreococcus tauri', 'Ostreococcus lucimarinus (strain CCE9901)', 'Chlorella variabilis', 'Klebsormidium flaccidum', 'Physcomitrella patens subsp. patens', 'Amborella trichopoda', 'Eragrostis tef', 'Setaria italica', 'Sorghum bicolor', 'Zea mays', 'Oryza longistaminata', 'Oryza rufipogon', 'Oryza sativa subsp. indica', 'Oryza sativa subsp. japonica', 'Oryza brachyantha', 'Oryza nivara', 'Oryza punctata', 'Oryza glaberrima', 'Brachypodium distachyon', 'Hordeum vulgare var. distichon', 'Triticum aestivum', 'Triticum urartu', 'Aegilops tauschii', 'Musa acuminata subsp. malaccensis', 'Solanum lycopersicum', 'Solanum tuberosum', 'Vitis vinifera', 'Populus trichocarpa', 'Manihot esculenta', 'Prunus persica', 'Glycine max', 'Medicago truncatula', 'Lotus japonicus', 'Gossypium hirsutum', 'Theobroma cacao', 'Arabidopsis thaliana', 'Arabidopsis lyrata', 'Brassica napus', 'Brassica rapa subsp. pekinensis', 'Brassica oleracea', 'Arabis alpina', 'Selaginella moellendorffii']

# %% [markdown]
# Make taxonomic dictionary, which is just a dict where the keys are all taxonomic levels of interest, and the values are a list containing the genomes beloning to that level

# %%
mytax_dic = make_tax_dic(all_plant_genomes)
mytax_dic
# Out:
# {'Aegilops': ['Aegilops tauschii'],
#  'Aegilops tauschii': ['Aegilops tauschii'],
#  'Amborella trichopoda': ['Amborella trichopoda'],
#  'Andropogoneae': ['Sorghum bicolor', 'Zea mays'],
#  'Andropogonodae': ['Sorghum bicolor', 'Zea mays'],
#  'Arabideae': ['Arabis alpina'],
#  'Arabidopsis': ['Arabidopsis thaliana', 'Arabidopsis lyrata'],
#  'Arabidopsis lyrata': ['Arabidopsis lyrata'],
#  'Arabidopsis thaliana': ['Arabidopsis thaliana'],
#  'Arabis alpina': ['Arabis alpina'],
#  'BOP clade': ['Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii'],
#  'Bathycoccaceae': ['Ostreococcus tauri',
#   'Ostreococcus lucimarinus (strain CCE9901)'],
#  'Brachypodieae': ['Brachypodium distachyon'],
#  'Brachypodium distachyon': ['Brachypodium distachyon'],
#  'Brassica': ['Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea'],
#  'Brassica campestris': ['Brassica rapa subsp. pekinensis'],
#  'Brassica napus': ['Brassica napus'],
#  'Brassica oleracea': ['Brassica oleracea'],
#  'Brassica rapa subsp. pekinensis': ['Brassica rapa subsp. pekinensis'],
#  'Brassicaceae': ['Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'Brassicales': ['Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'Brassiceae': ['Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea'],
#  'Bryophyta': ['Physcomitrella patens subsp. patens'],
#  'Byttnerioideae': ['Theobroma cacao'],
#  'Camelineae': ['Arabidopsis thaliana', 'Arabidopsis lyrata'],
#  'Chlamydomonadaceae': ['Chlamydomonas reinhardtii'],
#  'Chlamydomonadales': ['Chlamydomonas reinhardtii', 'Volvox carteri'],
#  'Chlamydomonas reinhardtii': ['Chlamydomonas reinhardtii'],
#  'Chlorella variabilis': ['Chlorella variabilis'],
#  'Chloridoideae': ['Eragrostis tef'],
#  'Chlorophyceae': ['Chlamydomonas reinhardtii', 'Volvox carteri'],
#  'Chlorophyta': ['Chlamydomonas reinhardtii',
#   'Volvox carteri',
#   'Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)',
#   'Micromonas pusilla (strain CCMP1545)',
#   'Ostreococcus tauri',
#   'Ostreococcus lucimarinus (strain CCE9901)',
#   'Chlorella variabilis'],
#  'Embryophyta': ['Physcomitrella patens subsp. patens',
#   'Amborella trichopoda',
#   'Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina',
#   'Selaginella moellendorffii'],
#  'Eragrostis tef': ['Eragrostis tef'],
#  'Eukaryota': ['Chlamydomonas reinhardtii',
#   'Volvox carteri',
#   'Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)',
#   'Micromonas pusilla (strain CCMP1545)',
#   'Ostreococcus tauri',
#   'Ostreococcus lucimarinus (strain CCE9901)',
#   'Chlorella variabilis',
#   'Klebsormidium flaccidum',
#   'Physcomitrella patens subsp. patens',
#   'Amborella trichopoda',
#   'Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina',
#   'Selaginella moellendorffii'],
#  'Euphorbiaceae': ['Manihot esculenta'],
#  'Euphyllophyta': ['Amborella trichopoda',
#   'Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'Fabaceae': ['Glycine max', 'Medicago truncatula', 'Lotus japonicus'],
#  'Fabales': ['Glycine max', 'Medicago truncatula', 'Lotus japonicus'],
#  'Glycine max': ['Glycine max'],
#  'Gossypium hirsutum': ['Gossypium hirsutum'],
#  'Gunneridae': ['Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'Hordeinae': ['Hordeum vulgare var. distichon'],
#  'Hordeum vulgare var. distichon': ['Hordeum vulgare var. distichon'],
#  'Klebsormidiophyceae': ['Klebsormidium flaccidum'],
#  'Klebsormidium flaccidum': ['Klebsormidium flaccidum'],
#  'LUCA': ['Ostreococcus lucimarinus (strain CCE9901)',
#   'Oryza longistaminata',
#   'Amborella trichopoda',
#   'Musa acuminata subsp. malaccensis',
#   'Brachypodium distachyon',
#   'Oryza rufipogon',
#   'Oryza punctata',
#   'Medicago truncatula',
#   'Sorghum bicolor',
#   'Ostreococcus tauri',
#   'Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)',
#   'Chlamydomonas reinhardtii',
#   'Brassica napus',
#   'Gossypium hirsutum',
#   'Arabis alpina',
#   'Solanum tuberosum',
#   'Physcomitrella patens subsp. patens',
#   'Solanum lycopersicum',
#   'Oryza sativa subsp. japonica',
#   'Oryza nivara',
#   'Chlorella variabilis',
#   'Lotus japonicus',
#   'Prunus persica',
#   'Oryza glaberrima',
#   'Zea mays',
#   'Arabidopsis thaliana',
#   'Manihot esculenta',
#   'Triticum aestivum',
#   'Vitis vinifera',
#   'Glycine max',
#   'Theobroma cacao',
#   'Arabidopsis lyrata',
#   'Aegilops tauschii',
#   'Eragrostis tef',
#   'Oryza sativa subsp. indica',
#   'Setaria italica',
#   'Volvox carteri',
#   'Brassica oleracea',
#   'Micromonas pusilla (strain CCMP1545)',
#   'Oryza brachyantha',
#   'Populus trichocarpa',
#   'Brassica rapa subsp. pekinensis',
#   'Selaginella moellendorffii',
#   'Hordeum vulgare var. distichon',
#   'Triticum urartu',
#   'Klebsormidium flaccidum'],
#  'Liliopsida': ['Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis'],
#  'Loteae': ['Lotus japonicus'],
#  'Lotus japonicus': ['Lotus japonicus'],
#  'Lycopersicon': ['Solanum lycopersicum'],
#  'Magnoliophyta': ['Amborella trichopoda',
#   'Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'Malpighiales': ['Populus trichocarpa', 'Manihot esculenta'],
#  'Malvaceae': ['Gossypium hirsutum', 'Theobroma cacao'],
#  'Malvales': ['Gossypium hirsutum', 'Theobroma cacao'],
#  'Mamiellaceae': ['Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)',
#   'Micromonas pusilla (strain CCMP1545)'],
#  'Mamiellales': ['Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)',
#   'Micromonas pusilla (strain CCMP1545)',
#   'Ostreococcus tauri',
#   'Ostreococcus lucimarinus (strain CCE9901)'],
#  'Mamiellophyceae': ['Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)',
#   'Micromonas pusilla (strain CCMP1545)',
#   'Ostreococcus tauri',
#   'Ostreococcus lucimarinus (strain CCE9901)'],
#  'Manihot esculenta': ['Manihot esculenta'],
#  'Medicago truncatula': ['Medicago truncatula'],
#  'Mesangiospermae': ['Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'Micromonas': ['Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)',
#   'Micromonas pusilla (strain CCMP1545)'],
#  'Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)': ['Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)'],
#  'Micromonas pusilla (strain CCMP1545)': ['Micromonas pusilla (strain CCMP1545)'],
#  'Musa': ['Musa acuminata subsp. malaccensis'],
#  'Musa acuminata': ['Musa acuminata subsp. malaccensis'],
#  'Musa acuminata subsp. malaccensis': ['Musa acuminata subsp. malaccensis'],
#  'Musaceae': ['Musa acuminata subsp. malaccensis'],
#  'Oryza': ['Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima'],
#  'Oryza brachyantha': ['Oryza brachyantha'],
#  'Oryza glaberrima': ['Oryza glaberrima'],
#  'Oryza longistaminata': ['Oryza longistaminata'],
#  'Oryza nivara': ['Oryza nivara'],
#  'Oryza punctata': ['Oryza punctata'],
#  'Oryza rufipogon': ['Oryza rufipogon'],
#  'Oryza sativa': ['Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica'],
#  'Oryza sativa subsp. indica': ['Oryza sativa subsp. indica'],
#  'Oryza sativa subsp. japonica': ['Oryza sativa subsp. japonica'],
#  'Oryzeae': ['Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima'],
#  'Oryzinae': ['Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima'],
#  'Oryzoideae': ['Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima'],
#  'Ostreococcus': ['Ostreococcus tauri',
#   'Ostreococcus lucimarinus (strain CCE9901)'],
#  "Ostreococcus 'lucimarinus'": ['Ostreococcus lucimarinus (strain CCE9901)'],
#  'Ostreococcus lucimarinus (strain CCE9901)': ['Ostreococcus lucimarinus (strain CCE9901)'],
#  'Ostreococcus tauri': ['Ostreococcus tauri'],
#  'PACMAD clade': ['Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays'],
#  'Panicoideae': ['Setaria italica', 'Sorghum bicolor', 'Zea mays'],
#  'Papilionoideae': ['Glycine max', 'Medicago truncatula', 'Lotus japonicus'],
#  'Pentapetalae': ['Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'Petrosaviidae': ['Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis'],
#  'Phaseoleae': ['Glycine max'],
#  'Physcomitrella patens subsp. patens': ['Physcomitrella patens subsp. patens'],
#  'Poaceae': ['Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii'],
#  'Poales': ['Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii'],
#  'Pooideae': ['Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii'],
#  'Populus trichocarpa': ['Populus trichocarpa'],
#  'Prunus persica': ['Prunus persica'],
#  'Selaginella moellendorffii': ['Selaginella moellendorffii'],
#  'Setaria italica': ['Setaria italica'],
#  'Solanaceae': ['Solanum lycopersicum', 'Solanum tuberosum'],
#  'Solanales': ['Solanum lycopersicum', 'Solanum tuberosum'],
#  'Solaneae': ['Solanum lycopersicum', 'Solanum tuberosum'],
#  'Solanoideae': ['Solanum lycopersicum', 'Solanum tuberosum'],
#  'Solanum': ['Solanum lycopersicum', 'Solanum tuberosum'],
#  'Solanum lycopersicum': ['Solanum lycopersicum'],
#  'Solanum tuberosum': ['Solanum tuberosum'],
#  'Sorghinae': ['Sorghum bicolor'],
#  'Sorghum bicolor': ['Sorghum bicolor'],
#  'Spermatophyta': ['Amborella trichopoda',
#   'Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'Streptophyta': ['Klebsormidium flaccidum',
#   'Physcomitrella patens subsp. patens',
#   'Amborella trichopoda',
#   'Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina',
#   'Selaginella moellendorffii'],
#  'Streptophytina': ['Physcomitrella patens subsp. patens',
#   'Amborella trichopoda',
#   'Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina',
#   'Selaginella moellendorffii'],
#  'Theobroma cacao': ['Theobroma cacao'],
#  'Tracheophyta': ['Amborella trichopoda',
#   'Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina',
#   'Selaginella moellendorffii'],
#  'Trebouxiophyceae': ['Chlorella variabilis'],
#  'Triticeae': ['Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii'],
#  'Triticinae': ['Triticum aestivum', 'Triticum urartu', 'Aegilops tauschii'],
#  'Triticodae': ['Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii'],
#  'Triticum': ['Triticum aestivum', 'Triticum urartu'],
#  'Triticum aestivum': ['Triticum aestivum'],
#  'Triticum urartu': ['Triticum urartu'],
#  'Viridiplantae': ['Chlamydomonas reinhardtii',
#   'Volvox carteri',
#   'Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)',
#   'Micromonas pusilla (strain CCMP1545)',
#   'Ostreococcus tauri',
#   'Ostreococcus lucimarinus (strain CCE9901)',
#   'Chlorella variabilis',
#   'Klebsormidium flaccidum',
#   'Physcomitrella patens subsp. patens',
#   'Amborella trichopoda',
#   'Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis',
#   'Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina',
#   'Selaginella moellendorffii'],
#  'Vitis vinifera': ['Vitis vinifera'],
#  'Volvox carteri': ['Volvox carteri'],
#  'Zea mays': ['Zea mays'],
#  'Zingiberales': ['Musa acuminata subsp. malaccensis'],
#  'asterids': ['Solanum lycopersicum', 'Solanum tuberosum'],
#  'commelinids': ['Eragrostis tef',
#   'Setaria italica',
#   'Sorghum bicolor',
#   'Zea mays',
#   'Oryza longistaminata',
#   'Oryza rufipogon',
#   'Oryza sativa subsp. indica',
#   'Oryza sativa subsp. japonica',
#   'Oryza brachyantha',
#   'Oryza nivara',
#   'Oryza punctata',
#   'Oryza glaberrima',
#   'Brachypodium distachyon',
#   'Hordeum vulgare var. distichon',
#   'Triticum aestivum',
#   'Triticum urartu',
#   'Aegilops tauschii',
#   'Musa acuminata subsp. malaccensis'],
#  'eudicotyledons': ['Solanum lycopersicum',
#   'Solanum tuberosum',
#   'Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'fabids': ['Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus'],
#  'lamiids': ['Solanum lycopersicum', 'Solanum tuberosum'],
#  'malvids': ['Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina'],
#  'prasinophytes': ['Micromonas commoda (strain RCC299 / NOUM17 / CCMP2709)',
#   'Micromonas pusilla (strain CCMP1545)',
#   'Ostreococcus tauri',
#   'Ostreococcus lucimarinus (strain CCE9901)'],
#  'rosids': ['Vitis vinifera',
#   'Populus trichocarpa',
#   'Manihot esculenta',
#   'Prunus persica',
#   'Glycine max',
#   'Medicago truncatula',
#   'Lotus japonicus',
#   'Gossypium hirsutum',
#   'Theobroma cacao',
#   'Arabidopsis thaliana',
#   'Arabidopsis lyrata',
#   'Brassica napus',
#   'Brassica rapa subsp. pekinensis',
#   'Brassica oleracea',
#   'Arabis alpina']}

# %% [markdown]
# - The following function gets all the genes at a given taxa level in a particular hog. I had to make this member_of_hog_id_v2 to replace the member_of_hog_id function in pyoma. Long story, but basically the pyoma function gets hung and stops working after many iterations. (See Vincent and Adrian for more clarification.)
# - Verification of the following example at: https://omabrowser.org/oma/hogs/ARATH00020/vis/. Let's test this HOG with it's string id, and a family int id. Let's compute HOG coverage (the proportion of species represented in a hog) at two levels, the recent level Arabidopsis, and the more ancient level, Viridiplantae.

# %%
hog_id = "HOG:0593989"
fam_id = 593989
taxon_levels = ["Viridiplantae", "Arabidopsis"]

# %%
for taxon_level in taxon_levels:
    print("There are", len(member_of_hog_id_v2(hog_id, taxon_level, mytax_dic)), "genes in", hog_id, "at", taxon_level)
# Out:
# /usr/local/lib/python3.6/site-packages/tables/leaf.py:396: PerformanceWarning: The Leaf ``/_i_HogLevel/ID/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)
# /usr/local/lib/python3.6/site-packages/tables/leaf.py:396: PerformanceWarning: The Leaf ``/_i_HogLevel/Level/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)
# There are 12 genes in HOG:0593989 at Viridiplantae
# There are 3 genes in HOG:0593989 at Arabidopsis

# %% [markdown]
# This function counts the number of species in a given hog. Can take either a string hog_id or an int family number.

# %%
for taxon_level in taxon_levels:
    print("There are", get_nb_species_in_hog_v2(hog_id, taxon_level, mytax_dic), "species in", hog_id, "at", taxon_level)
    print("There are", get_nb_species_in_hog_v2(fam_id, taxon_level, mytax_dic), "species in family", fam_id, "at", taxon_level, "\n")
# Out:
# There are 11 species in HOG:0593989 at Viridiplantae
# There are 11 species in family 593989 at Viridiplantae
#
# There are 2 species in HOG:0593989 at Arabidopsis
# There are 2 species in family 593989 at Arabidopsis

# %% [markdown]
# This final function computes the HOG Coverage, which is simply the number of species in a given hog/ the number of species that potentially could be in that hog.
# The function returns: nb_species_in_hog, nb_species_possible_in_hog, hog_coverage

# %%
for taxon_level in taxon_levels:
    hog_cov_result = get_hog_coverage(hog_id, taxon_level, mytax_dic)
    print("There are", hog_cov_result[0], "species in this hog;", 
          hog_cov_result[1], "species possible in this hog; thus", 
          hog_cov_result[2],"hog coverage")
# Out:
# There are 11 species in this hog; 46 species possible in this hog; thus 0.2391304347826087 hog coverage
# There are 2 species in this hog; 2 species possible in this hog; thus 1.0 hog coverage
